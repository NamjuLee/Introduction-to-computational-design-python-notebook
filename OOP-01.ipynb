# %%
import math
import random

# %%
class Round:
  def __init__(self, history, index):
    self.index = index;
    self.history = history
    self.dataFight = []
  def Update(self, log ):
    self.dataFight.append(log)
  def PrintHistory(self):
    for i in self.dataFight:
        print(i)
class History:
  def __init__(self, person):
    self.person = person
    self.rounds = [Round(self, 0)]
  def NewRound(self):
    self.rounds.append(Round(self, len(self.rounds)))
  def Update(self, log ):
    self.rounds[-1].Update(log)
  def PrintHistory(self):
    for i in self.rounds:
        print('---------------------')
        i.PrintHistory();
class Person:
  def __init__(self, name, age = 20):
    self.name = name
    self.age = age
    self.energy = 100;
    self.numOfKill = 0;
    self.isAlive = True;
    self.other = None;
    self.power = math.floor(random.random() * 10)
    self.history = History(self)
  def Rest(self):
    self.energy += 10;
  def HitByNum(self, other, num):
    for i in range(num):
        self.Hit(other)
  def Hit(self, other):
#     self.energy += math.floor(random.random() * 0.9)   
    other.energy -= self.power
    self.ReportFight(other); # for report
    if(other.energy < 0):
        self.Kill(other)
  def ReportFight(self, other):
    log = self.name,'(', self.energy ,')', ' is fighting with ', other.name,'(', other.energy ,')'
    print(log);
    self.history.Update(log);
  def Print(self):
    if(self.isAlive):
        print('name:', self.name, ', age:', self.age, ', power:', self.power, ', energy:', self.energy  )
    else:
        print(self.name, 'is gone...by', self.other.name ) 
  def Kill(self, person):
    self.numOfKill += 1
    person.isAlive = False
    person.other = self
    self.history.NewRound()
  def PrintHistory(self):
    self.history.PrintHistory();
    
nj = Person('nj', 30)
hj = Person('hj', 18)

# %%
nj.Print()
hj.Print()

hj.Hit(nj)

nj.Print()
hj.Print()
# Out:
# name: nj , age: 30 , power: 2 , energy: 100
# name: hj , age: 18 , power: 7 , energy: 100
# ('hj', '(', 100, ')', ' is fighting with ', 'nj', '(', 93, ')')
# name: nj , age: 30 , power: 2 , energy: 93
# name: hj , age: 18 , power: 7 , energy: 100

# %%
hj.Kill(nj)
nj.Print()
hj.Print()
# Out:
# nj is gone...by hj
# name: hj , age: 18 , power: 7 , energy: 100

# %%
ww = Person('ww', 50)


hj.HitByNum(ww, 12)
# for i in range(12):
#     hj.Hit(ww)

ww.Print()
hj.Print()
# Out:
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 93, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 86, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 79, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 72, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 65, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 58, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 51, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 44, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 37, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 30, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 23, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 16, ')')
# name: ww , age: 50 , power: 6 , energy: 16
# name: hj , age: 18 , power: 7 , energy: 100

# %%
class Game:
  def __init__(self, names):
    self.people = [ Person(i) for i in names ]
  def Log(self):
    for i in self.people:
        i.Print()
  def PlanGame(self):
    match = self.GetRandomIndex(len(self.people))
    
    remain = []
    
    for i in match:
        print('------------------')
        print(i[0],':', self.people[i[0]].name ,i[1],':', self.people[i[1]].name  )
        self.Fight(self.people[i[0]], self.people[i[1]])
        if(self.people[i[0]].isAlive):
            print('------------------')
            print(i[0],':', self.people[i[0]].name, 'winner')
        else :
            print('------------------')
            print(i[1],':', self.people[i[1]].name, 'winner')

  def Fight(self, otherA , otherB ):
      while(otherA.isAlive and otherB.isAlive):
          self.Hit(otherA, otherB)
        
  def Hit(self, otherA , otherB ):
        time = random.random()
        if(time < 0.5):
            otherA.Hit(otherB)
        else:
            otherB.Hit(otherA)
  def GetRandomIndex(self, theLength):
    d = [i for i in range(theLength)]
    temp = []
    while(len(d)):
        out = d.pop( math.floor(random.random() * len(d)))
        temp.append(out);
    myReturn = [];
    for i in range(0, len(temp), 2):
        myReturn.append([temp[i], temp[i+1]])
    return myReturn

# %%
names = [ 'nj', 'mj' , 'dj' , 'aj', 'kj', 'wj', 'hj', 'oj']
game = Game(names)
# game.Log()
game.PlanGame()
# Out:
# ------------------
# 5 : wj 0 : nj
# ('wj', '(', 100, ')', ' is fighting with ', 'nj', '(', 97, ')')
# ('nj', '(', 97, ')', ' is fighting with ', 'wj', '(', 99, ')')
# ('wj', '(', 99, ')', ' is fighting with ', 'nj', '(', 94, ')')
# ('nj', '(', 94, ')', ' is fighting with ', 'wj', '(', 98, ')')
# ('wj', '(', 98, ')', ' is fighting with ', 'nj', '(', 91, ')')
# ('wj', '(', 98, ')', ' is fighting with ', 'nj', '(', 88, ')')
# ('nj', '(', 88, ')', ' is fighting with ', 'wj', '(', 97, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 85, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 82, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 79, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 76, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 73, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 70, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 67, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 64, ')')
# ('wj', '(', 97, ')', ' is fighting with ', 'nj', '(', 61, ')')
# ('nj', '(', 61, ')', ' is fighting with ', 'wj', '(', 96, ')')
# ('nj', '(', 61, ')', ' is fighting with ', 'wj', '(', 95, ')')
# ('wj', '(', 95, ')', ' is fighting with ', 'nj', '(', 58, ')')
# ('nj', '(', 58, ')', ' is fighting with ', 'wj', '(', 94, ')')
# ('wj', '(', 94, ')', ' is fighting with ', 'nj', '(', 55, ')')
# ('wj', '(', 94, ')', ' is fighting with ', 'nj', '(', 52, ')')
# ('nj', '(', 52, ')', ' is fighting with ', 'wj', '(', 93, ')')
# ('wj', '(', 93, ')', ' is fighting with ', 'nj', '(', 49, ')')
# ('wj', '(', 93, ')', ' is fighting with ', 'nj', '(', 46, ')')
# ('nj', '(', 46, ')', ' is fighting with ', 'wj', '(', 92, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 43, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 40, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 37, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 34, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 31, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 28, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 25, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 22, ')')
# ('wj', '(', 92, ')', ' is fighting with ', 'nj', '(', 19, ')')
# ('nj', '(', 19, ')', ' is fighting with ', 'wj', '(', 91, ')')
# ('nj', '(', 19, ')', ' is fighting with ', 'wj', '(', 90, ')')
# ('nj', '(', 19, ')', ' is fighting with ', 'wj', '(', 89, ')')
# ('wj', '(', 89, ')', ' is fighting with ', 'nj', '(', 16, ')')
# ('wj', '(', 89, ')', ' is fighting with ', 'nj', '(', 13, ')')
# ('nj', '(', 13, ')', ' is fighting with ', 'wj', '(', 88, ')')
# ('wj', '(', 88, ')', ' is fighting with ', 'nj', '(', 10, ')')
# ('nj', '(', 10, ')', ' is fighting with ', 'wj', '(', 87, ')')
# ('wj', '(', 87, ')', ' is fighting with ', 'nj', '(', 7, ')')
# ('nj', '(', 7, ')', ' is fighting with ', 'wj', '(', 86, ')')
# ('wj', '(', 86, ')', ' is fighting with ', 'nj', '(', 4, ')')
# ('wj', '(', 86, ')', ' is fighting with ', 'nj', '(', 1, ')')
# ('wj', '(', 86, ')', ' is fighting with ', 'nj', '(', -2, ')')
# ------------------
# 5 : wj winner
# ------------------
# 2 : dj 3 : aj
# ('aj', '(', 100, ')', ' is fighting with ', 'dj', '(', 97, ')')
# ('aj', '(', 100, ')', ' is fighting with ', 'dj', '(', 94, ')')
# ('dj', '(', 94, ')', ' is fighting with ', 'aj', '(', 95, ')')
# ('dj', '(', 94, ')', ' is fighting with ', 'aj', '(', 90, ')')
# ('aj', '(', 90, ')', ' is fighting with ', 'dj', '(', 91, ')')
# ('dj', '(', 91, ')', ' is fighting with ', 'aj', '(', 85, ')')
# ('dj', '(', 91, ')', ' is fighting with ', 'aj', '(', 80, ')')
# ('aj', '(', 80, ')', ' is fighting with ', 'dj', '(', 88, ')')
# ('dj', '(', 88, ')', ' is fighting with ', 'aj', '(', 75, ')')
# ('aj', '(', 75, ')', ' is fighting with ', 'dj', '(', 85, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 70, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 65, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 60, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 55, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 50, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 45, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 40, ')')
# ('dj', '(', 85, ')', ' is fighting with ', 'aj', '(', 35, ')')
# ('aj', '(', 35, ')', ' is fighting with ', 'dj', '(', 82, ')')
# ('dj', '(', 82, ')', ' is fighting with ', 'aj', '(', 30, ')')
# ('aj', '(', 30, ')', ' is fighting with ', 'dj', '(', 79, ')')
# ('dj', '(', 79, ')', ' is fighting with ', 'aj', '(', 25, ')')
# ('aj', '(', 25, ')', ' is fighting with ', 'dj', '(', 76, ')')
# ('aj', '(', 25, ')', ' is fighting with ', 'dj', '(', 73, ')')
# ('dj', '(', 73, ')', ' is fighting with ', 'aj', '(', 20, ')')
# ('dj', '(', 73, ')', ' is fighting with ', 'aj', '(', 15, ')')
# ('aj', '(', 15, ')', ' is fighting with ', 'dj', '(', 70, ')')
# ('aj', '(', 15, ')', ' is fighting with ', 'dj', '(', 67, ')')
# ('aj', '(', 15, ')', ' is fighting with ', 'dj', '(', 64, ')')
# ('aj', '(', 15, ')', ' is fighting with ', 'dj', '(', 61, ')')
# ('dj', '(', 61, ')', ' is fighting with ', 'aj', '(', 10, ')')
# ('aj', '(', 10, ')', ' is fighting with ', 'dj', '(', 58, ')')
# ('aj', '(', 10, ')', ' is fighting with ', 'dj', '(', 55, ')')
# ('aj', '(', 10, ')', ' is fighting with ', 'dj', '(', 52, ')')
# ('dj', '(', 52, ')', ' is fighting with ', 'aj', '(', 5, ')')
# ('dj', '(', 52, ')', ' is fighting with ', 'aj', '(', 0, ')')
# ('aj', '(', 0, ')', ' is fighting with ', 'dj', '(', 49, ')')
# ('dj', '(', 49, ')', ' is fighting with ', 'aj', '(', -5, ')')
# ------------------
# 2 : dj winner
# ------------------
# 6 : hj 7 : oj
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 91, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 82, ')')
# ('hj', '(', 82, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 73, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 64, ')')
# ('hj', '(', 64, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('hj', '(', 64, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 55, ')')
# ('hj', '(', 55, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('hj', '(', 55, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('hj', '(', 55, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 46, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 37, ')')
# ('hj', '(', 37, ')', ' is fighting with ', 'oj', '(', 100, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 28, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 19, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 10, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 1, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', -8, ')')
# ------------------
# 7 : oj winner
# ------------------
# 4 : kj 1 : mj
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 99, ')')
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 98, ')')
# ('kj', '(', 98, ')', ' is fighting with ', 'mj', '(', 94, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 97, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 96, ')')
# ('kj', '(', 96, ')', ' is fighting with ', 'mj', '(', 88, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'kj', '(', 95, ')')
# ('kj', '(', 95, ')', ' is fighting with ', 'mj', '(', 82, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'kj', '(', 94, ')')
# ('kj', '(', 94, ')', ' is fighting with ', 'mj', '(', 76, ')')
# ('kj', '(', 94, ')', ' is fighting with ', 'mj', '(', 70, ')')
# ('mj', '(', 70, ')', ' is fighting with ', 'kj', '(', 93, ')')
# ('kj', '(', 93, ')', ' is fighting with ', 'mj', '(', 64, ')')
# ('kj', '(', 93, ')', ' is fighting with ', 'mj', '(', 58, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 92, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 91, ')')
# ('kj', '(', 91, ')', ' is fighting with ', 'mj', '(', 52, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 90, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 89, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 88, ')')
# ('kj', '(', 88, ')', ' is fighting with ', 'mj', '(', 46, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 87, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 86, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 85, ')')
# ('kj', '(', 85, ')', ' is fighting with ', 'mj', '(', 40, ')')
# ('kj', '(', 85, ')', ' is fighting with ', 'mj', '(', 34, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 84, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 83, ')')
# ('kj', '(', 83, ')', ' is fighting with ', 'mj', '(', 28, ')')
# ('kj', '(', 83, ')', ' is fighting with ', 'mj', '(', 22, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'kj', '(', 82, ')')
# ('kj', '(', 82, ')', ' is fighting with ', 'mj', '(', 16, ')')
# ('kj', '(', 82, ')', ' is fighting with ', 'mj', '(', 10, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 81, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 80, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'mj', '(', 4, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'mj', '(', -2, ')')
# ------------------
# 4 : kj winner

# %%
game.Fight(game.people[0], game.people[1])
game.Log()
# Out:
# nj is gone...by wj
# mj is gone...by kj
# name: dj , age: 20 , power: 5 , energy: 49
# aj is gone...by dj
# name: kj , age: 20 , power: 6 , energy: 80
# name: wj , age: 20 , power: 3 , energy: 86
# hj is gone...by oj
# name: oj , age: 20 , power: 9 , energy: 100

# %%
game.people[1].Print()
game.people[1].PrintHistory()
# Out:
# mj is gone...by kj
# ---------------------
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 99, ')')
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 98, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 97, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 96, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'kj', '(', 95, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'kj', '(', 94, ')')
# ('mj', '(', 70, ')', ' is fighting with ', 'kj', '(', 93, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 92, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 91, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 90, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 89, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 88, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 87, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 86, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 85, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 84, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 83, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'kj', '(', 82, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 81, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 80, ')')

# %%
game.Fight(game.people[1], game.people[2])
game.people[1].Print()
game.people[1].PrintHistory()
# Out:
# mj is gone...by kj
# ---------------------
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 99, ')')
# ('mj', '(', 100, ')', ' is fighting with ', 'kj', '(', 98, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 97, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'kj', '(', 96, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'kj', '(', 95, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'kj', '(', 94, ')')
# ('mj', '(', 70, ')', ' is fighting with ', 'kj', '(', 93, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 92, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'kj', '(', 91, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 90, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 89, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'kj', '(', 88, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 87, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 86, ')')
# ('mj', '(', 46, ')', ' is fighting with ', 'kj', '(', 85, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 84, ')')
# ('mj', '(', 34, ')', ' is fighting with ', 'kj', '(', 83, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'kj', '(', 82, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 81, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'kj', '(', 80, ')')
