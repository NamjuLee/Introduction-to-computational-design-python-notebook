# %% [markdown]
# ### example Class
# ----
# ##### instructor: NJ Namju Lee
# ##### nj.namju@gmail.com
# ##### www.njstudio.co.kr

# %%
import math
import random

# %%
class Round:
  def __init__(self, history, index):
    self.index = index;
    self.history = history
    self.dataFight = []
  def Update(self, log ):
    self.dataFight.append(log)
  def PrintHistory(self):
    for i in self.dataFight:
        print(i)
class History:
  def __init__(self, person):
    self.person = person
    self.rounds = [Round(self, 0)]
  def NewRound(self):
    self.rounds.append(Round(self, len(self.rounds)))
  def Update(self, log ):
    self.rounds[-1].Update(log)
  def PrintHistory(self):
    for i in self.rounds:
        print('---------------------')
        i.PrintHistory();
class Person:
  def __init__(self, name, age = 20):
    self.name = name
    self.age = age
    self.energy = 100;
    self.numOfKill = 0;
    self.isAlive = True;
    self.other = None;
    self.power = math.floor(random.random() * 10)
    self.history = History(self)
  def Rest(self):
    self.energy += 10;
  def HitByNum(self, other, num):
    for i in range(num):
        self.Hit(other)
  def Hit(self, other):
#     self.energy += math.floor(random.random() * 0.9)   
    other.energy -= self.power
    self.ReportFight(other); # for report
    if(other.energy < 0):
        self.Kill(other)
  def ReportFight(self, other):
    log = self.name,'(', self.energy ,')', ' is fighting with ', other.name,'(', other.energy ,')'
    print(log);
    self.history.Update(log);
  def Print(self):
    if(self.isAlive):
        print('name:', self.name, ', age:', self.age, ', power:', self.power, ', energy:', self.energy  )
    else:
        print(self.name, 'is gone...by', self.other.name ) 
  def Kill(self, person):
    self.numOfKill += 1
    person.isAlive = False
    person.other = self
    self.history.NewRound()
  def PrintHistory(self):
    self.history.PrintHistory();
    
nj = Person('nj', 30)
hj = Person('hj', 18)

# %%
nj.Print()
hj.Print()

hj.Hit(nj)

nj.Print()
hj.Print()
# Out:
# name: nj , age: 30 , power: 1 , energy: 97
# name: hj , age: 18 , power: 3 , energy: 100
# ('hj', '(', 100, ')', ' is fighting with ', 'nj', '(', 94, ')')
# name: nj , age: 30 , power: 1 , energy: 94
# name: hj , age: 18 , power: 3 , energy: 100

# %%
hj.Kill(nj)
nj.Print()
hj.Print()
# Out:
# nj is gone...by hj
# name: hj , age: 18 , power: 0 , energy: 100

# %%
ww = Person('ww', 50)


hj.HitByNum(ww, 12)
# for i in range(12):
#     hj.Hit(ww)

ww.Print()
hj.Print()
# Out:
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 97, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 94, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 91, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 88, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 85, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 82, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 79, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 76, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 73, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 70, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 67, ')')
# ('hj', '(', 100, ')', ' is fighting with ', 'ww', '(', 64, ')')
# name: ww , age: 50 , power: 1 , energy: 64
# name: hj , age: 18 , power: 3 , energy: 100

# %%
class Game:
  def __init__(self, names):
    self.people = [ Person(i) for i in names ]
  def Log(self):
    for i in self.people:
        i.Print()
  def PlanGame(self):
    match = self.GetRandomIndex(len(self.people))
    
    remain = []
    
    for i in match:
        print('------------------')
        print(i[0],':', self.people[i[0]].name ,i[1],':', self.people[i[1]].name  )
        self.Fight(self.people[i[0]], self.people[i[1]])
        if(self.people[i[0]].isAlive):
            print('------------------')
            print(i[0],':', self.people[i[0]].name, 'winner')
        else :
            print('------------------')
            print(i[1],':', self.people[i[1]].name, 'winner')

  def Fight(self, otherA , otherB ):
      while(otherA.isAlive and otherB.isAlive):
          self.Hit(otherA, otherB)
        
  def Hit(self, otherA , otherB ):
        time = random.random()
        if(time < 0.5):
            otherA.Hit(otherB)
        else:
            otherB.Hit(otherA)
  def GetRandomIndex(self, theLength):
    d = [i for i in range(theLength)]
    temp = []
    while(len(d)):
        out = d.pop( math.floor(random.random() * len(d)))
        temp.append(out);
    myReturn = [];
    for i in range(0, len(temp), 2):
        myReturn.append([temp[i], temp[i+1]])
    return myReturn

# %%
names = [ 'nj', 'mj' , 'dj' , 'aj', 'kj', 'wj', 'hj', 'oj']
game = Game(names)
# game.Log()
game.PlanGame()
# Out:
# ------------------
# 3 : aj 0 : nj
# ('nj', '(', 100, ')', ' is fighting with ', 'aj', '(', 92, ')')
# ('aj', '(', 92, ')', ' is fighting with ', 'nj', '(', 91, ')')
# ('aj', '(', 92, ')', ' is fighting with ', 'nj', '(', 82, ')')
# ('nj', '(', 82, ')', ' is fighting with ', 'aj', '(', 84, ')')
# ('nj', '(', 82, ')', ' is fighting with ', 'aj', '(', 76, ')')
# ('aj', '(', 76, ')', ' is fighting with ', 'nj', '(', 73, ')')
# ('aj', '(', 76, ')', ' is fighting with ', 'nj', '(', 64, ')')
# ('nj', '(', 64, ')', ' is fighting with ', 'aj', '(', 68, ')')
# ('aj', '(', 68, ')', ' is fighting with ', 'nj', '(', 55, ')')
# ('nj', '(', 55, ')', ' is fighting with ', 'aj', '(', 60, ')')
# ('aj', '(', 60, ')', ' is fighting with ', 'nj', '(', 46, ')')
# ('nj', '(', 46, ')', ' is fighting with ', 'aj', '(', 52, ')')
# ('aj', '(', 52, ')', ' is fighting with ', 'nj', '(', 37, ')')
# ('aj', '(', 52, ')', ' is fighting with ', 'nj', '(', 28, ')')
# ('aj', '(', 52, ')', ' is fighting with ', 'nj', '(', 19, ')')
# ('nj', '(', 19, ')', ' is fighting with ', 'aj', '(', 44, ')')
# ('nj', '(', 19, ')', ' is fighting with ', 'aj', '(', 36, ')')
# ('aj', '(', 36, ')', ' is fighting with ', 'nj', '(', 10, ')')
# ('aj', '(', 36, ')', ' is fighting with ', 'nj', '(', 1, ')')
# ('nj', '(', 1, ')', ' is fighting with ', 'aj', '(', 28, ')')
# ('aj', '(', 28, ')', ' is fighting with ', 'nj', '(', -8, ')')
# ------------------
# 3 : aj winner
# ------------------
# 2 : dj 4 : kj
# ('kj', '(', 100, ')', ' is fighting with ', 'dj', '(', 98, ')')
# ('dj', '(', 98, ')', ' is fighting with ', 'kj', '(', 98, ')')
# ('dj', '(', 98, ')', ' is fighting with ', 'kj', '(', 96, ')')
# ('kj', '(', 96, ')', ' is fighting with ', 'dj', '(', 96, ')')
# ('kj', '(', 96, ')', ' is fighting with ', 'dj', '(', 94, ')')
# ('kj', '(', 96, ')', ' is fighting with ', 'dj', '(', 92, ')')
# ('kj', '(', 96, ')', ' is fighting with ', 'dj', '(', 90, ')')
# ('dj', '(', 90, ')', ' is fighting with ', 'kj', '(', 94, ')')
# ('kj', '(', 94, ')', ' is fighting with ', 'dj', '(', 88, ')')
# ('kj', '(', 94, ')', ' is fighting with ', 'dj', '(', 86, ')')
# ('kj', '(', 94, ')', ' is fighting with ', 'dj', '(', 84, ')')
# ('dj', '(', 84, ')', ' is fighting with ', 'kj', '(', 92, ')')
# ('dj', '(', 84, ')', ' is fighting with ', 'kj', '(', 90, ')')
# ('dj', '(', 84, ')', ' is fighting with ', 'kj', '(', 88, ')')
# ('kj', '(', 88, ')', ' is fighting with ', 'dj', '(', 82, ')')
# ('dj', '(', 82, ')', ' is fighting with ', 'kj', '(', 86, ')')
# ('dj', '(', 82, ')', ' is fighting with ', 'kj', '(', 84, ')')
# ('kj', '(', 84, ')', ' is fighting with ', 'dj', '(', 80, ')')
# ('kj', '(', 84, ')', ' is fighting with ', 'dj', '(', 78, ')')
# ('kj', '(', 84, ')', ' is fighting with ', 'dj', '(', 76, ')')
# ('dj', '(', 76, ')', ' is fighting with ', 'kj', '(', 82, ')')
# ('dj', '(', 76, ')', ' is fighting with ', 'kj', '(', 80, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'dj', '(', 74, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'dj', '(', 72, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'dj', '(', 70, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'dj', '(', 68, ')')
# ('kj', '(', 80, ')', ' is fighting with ', 'dj', '(', 66, ')')
# ('dj', '(', 66, ')', ' is fighting with ', 'kj', '(', 78, ')')
# ('dj', '(', 66, ')', ' is fighting with ', 'kj', '(', 76, ')')
# ('kj', '(', 76, ')', ' is fighting with ', 'dj', '(', 64, ')')
# ('kj', '(', 76, ')', ' is fighting with ', 'dj', '(', 62, ')')
# ('kj', '(', 76, ')', ' is fighting with ', 'dj', '(', 60, ')')
# ('dj', '(', 60, ')', ' is fighting with ', 'kj', '(', 74, ')')
# ('kj', '(', 74, ')', ' is fighting with ', 'dj', '(', 58, ')')
# ('dj', '(', 58, ')', ' is fighting with ', 'kj', '(', 72, ')')
# ('kj', '(', 72, ')', ' is fighting with ', 'dj', '(', 56, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 70, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 68, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 66, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 64, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 62, ')')
# ('dj', '(', 56, ')', ' is fighting with ', 'kj', '(', 60, ')')
# ('kj', '(', 60, ')', ' is fighting with ', 'dj', '(', 54, ')')
# ('dj', '(', 54, ')', ' is fighting with ', 'kj', '(', 58, ')')
# ('dj', '(', 54, ')', ' is fighting with ', 'kj', '(', 56, ')')
# ('kj', '(', 56, ')', ' is fighting with ', 'dj', '(', 52, ')')
# ('kj', '(', 56, ')', ' is fighting with ', 'dj', '(', 50, ')')
# ('kj', '(', 56, ')', ' is fighting with ', 'dj', '(', 48, ')')
# ('dj', '(', 48, ')', ' is fighting with ', 'kj', '(', 54, ')')
# ('dj', '(', 48, ')', ' is fighting with ', 'kj', '(', 52, ')')
# ('dj', '(', 48, ')', ' is fighting with ', 'kj', '(', 50, ')')
# ('kj', '(', 50, ')', ' is fighting with ', 'dj', '(', 46, ')')
# ('dj', '(', 46, ')', ' is fighting with ', 'kj', '(', 48, ')')
# ('kj', '(', 48, ')', ' is fighting with ', 'dj', '(', 44, ')')
# ('dj', '(', 44, ')', ' is fighting with ', 'kj', '(', 46, ')')
# ('kj', '(', 46, ')', ' is fighting with ', 'dj', '(', 42, ')')
# ('kj', '(', 46, ')', ' is fighting with ', 'dj', '(', 40, ')')
# ('dj', '(', 40, ')', ' is fighting with ', 'kj', '(', 44, ')')
# ('dj', '(', 40, ')', ' is fighting with ', 'kj', '(', 42, ')')
# ('dj', '(', 40, ')', ' is fighting with ', 'kj', '(', 40, ')')
# ('dj', '(', 40, ')', ' is fighting with ', 'kj', '(', 38, ')')
# ('dj', '(', 40, ')', ' is fighting with ', 'kj', '(', 36, ')')
# ('kj', '(', 36, ')', ' is fighting with ', 'dj', '(', 38, ')')
# ('kj', '(', 36, ')', ' is fighting with ', 'dj', '(', 36, ')')
# ('dj', '(', 36, ')', ' is fighting with ', 'kj', '(', 34, ')')
# ('kj', '(', 34, ')', ' is fighting with ', 'dj', '(', 34, ')')
# ('dj', '(', 34, ')', ' is fighting with ', 'kj', '(', 32, ')')
# ('kj', '(', 32, ')', ' is fighting with ', 'dj', '(', 32, ')')
# ('dj', '(', 32, ')', ' is fighting with ', 'kj', '(', 30, ')')
# ('dj', '(', 32, ')', ' is fighting with ', 'kj', '(', 28, ')')
# ('dj', '(', 32, ')', ' is fighting with ', 'kj', '(', 26, ')')
# ('dj', '(', 32, ')', ' is fighting with ', 'kj', '(', 24, ')')
# ('kj', '(', 24, ')', ' is fighting with ', 'dj', '(', 30, ')')
# ('dj', '(', 30, ')', ' is fighting with ', 'kj', '(', 22, ')')
# ('dj', '(', 30, ')', ' is fighting with ', 'kj', '(', 20, ')')
# ('kj', '(', 20, ')', ' is fighting with ', 'dj', '(', 28, ')')
# ('dj', '(', 28, ')', ' is fighting with ', 'kj', '(', 18, ')')
# ('dj', '(', 28, ')', ' is fighting with ', 'kj', '(', 16, ')')
# ('kj', '(', 16, ')', ' is fighting with ', 'dj', '(', 26, ')')
# ('kj', '(', 16, ')', ' is fighting with ', 'dj', '(', 24, ')')
# ('dj', '(', 24, ')', ' is fighting with ', 'kj', '(', 14, ')')
# ('dj', '(', 24, ')', ' is fighting with ', 'kj', '(', 12, ')')
# ('dj', '(', 24, ')', ' is fighting with ', 'kj', '(', 10, ')')
# ('kj', '(', 10, ')', ' is fighting with ', 'dj', '(', 22, ')')
# ('dj', '(', 22, ')', ' is fighting with ', 'kj', '(', 8, ')')
# ('kj', '(', 8, ')', ' is fighting with ', 'dj', '(', 20, ')')
# ('dj', '(', 20, ')', ' is fighting with ', 'kj', '(', 6, ')')
# ('dj', '(', 20, ')', ' is fighting with ', 'kj', '(', 4, ')')
# ('dj', '(', 20, ')', ' is fighting with ', 'kj', '(', 2, ')')
# ('kj', '(', 2, ')', ' is fighting with ', 'dj', '(', 18, ')')
# ('dj', '(', 18, ')', ' is fighting with ', 'kj', '(', 0, ')')
# ('dj', '(', 18, ')', ' is fighting with ', 'kj', '(', -2, ')')
# ------------------
# 2 : dj winner
# ------------------
# 6 : hj 7 : oj
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 98, ')')
# ('oj', '(', 100, ')', ' is fighting with ', 'hj', '(', 96, ')')
# ('hj', '(', 96, ')', ' is fighting with ', 'oj', '(', 96, ')')
# ('oj', '(', 96, ')', ' is fighting with ', 'hj', '(', 94, ')')
# ('oj', '(', 96, ')', ' is fighting with ', 'hj', '(', 92, ')')
# ('hj', '(', 92, ')', ' is fighting with ', 'oj', '(', 92, ')')
# ('hj', '(', 92, ')', ' is fighting with ', 'oj', '(', 88, ')')
# ('oj', '(', 88, ')', ' is fighting with ', 'hj', '(', 90, ')')
# ('hj', '(', 90, ')', ' is fighting with ', 'oj', '(', 84, ')')
# ('oj', '(', 84, ')', ' is fighting with ', 'hj', '(', 88, ')')
# ('hj', '(', 88, ')', ' is fighting with ', 'oj', '(', 80, ')')
# ('hj', '(', 88, ')', ' is fighting with ', 'oj', '(', 76, ')')
# ('hj', '(', 88, ')', ' is fighting with ', 'oj', '(', 72, ')')
# ('hj', '(', 88, ')', ' is fighting with ', 'oj', '(', 68, ')')
# ('hj', '(', 88, ')', ' is fighting with ', 'oj', '(', 64, ')')
# ('oj', '(', 64, ')', ' is fighting with ', 'hj', '(', 86, ')')
# ('oj', '(', 64, ')', ' is fighting with ', 'hj', '(', 84, ')')
# ('hj', '(', 84, ')', ' is fighting with ', 'oj', '(', 60, ')')
# ('hj', '(', 84, ')', ' is fighting with ', 'oj', '(', 56, ')')
# ('hj', '(', 84, ')', ' is fighting with ', 'oj', '(', 52, ')')
# ('oj', '(', 52, ')', ' is fighting with ', 'hj', '(', 82, ')')
# ('oj', '(', 52, ')', ' is fighting with ', 'hj', '(', 80, ')')
# ('oj', '(', 52, ')', ' is fighting with ', 'hj', '(', 78, ')')
# ('oj', '(', 52, ')', ' is fighting with ', 'hj', '(', 76, ')')
# ('oj', '(', 52, ')', ' is fighting with ', 'hj', '(', 74, ')')
# ('hj', '(', 74, ')', ' is fighting with ', 'oj', '(', 48, ')')
# ('hj', '(', 74, ')', ' is fighting with ', 'oj', '(', 44, ')')
# ('hj', '(', 74, ')', ' is fighting with ', 'oj', '(', 40, ')')
# ('oj', '(', 40, ')', ' is fighting with ', 'hj', '(', 72, ')')
# ('oj', '(', 40, ')', ' is fighting with ', 'hj', '(', 70, ')')
# ('oj', '(', 40, ')', ' is fighting with ', 'hj', '(', 68, ')')
# ('oj', '(', 40, ')', ' is fighting with ', 'hj', '(', 66, ')')
# ('oj', '(', 40, ')', ' is fighting with ', 'hj', '(', 64, ')')
# ('hj', '(', 64, ')', ' is fighting with ', 'oj', '(', 36, ')')
# ('hj', '(', 64, ')', ' is fighting with ', 'oj', '(', 32, ')')
# ('oj', '(', 32, ')', ' is fighting with ', 'hj', '(', 62, ')')
# ('oj', '(', 32, ')', ' is fighting with ', 'hj', '(', 60, ')')
# ('hj', '(', 60, ')', ' is fighting with ', 'oj', '(', 28, ')')
# ('oj', '(', 28, ')', ' is fighting with ', 'hj', '(', 58, ')')
# ('oj', '(', 28, ')', ' is fighting with ', 'hj', '(', 56, ')')
# ('hj', '(', 56, ')', ' is fighting with ', 'oj', '(', 24, ')')
# ('hj', '(', 56, ')', ' is fighting with ', 'oj', '(', 20, ')')
# ('hj', '(', 56, ')', ' is fighting with ', 'oj', '(', 16, ')')
# ('oj', '(', 16, ')', ' is fighting with ', 'hj', '(', 54, ')')
# ('oj', '(', 16, ')', ' is fighting with ', 'hj', '(', 52, ')')
# ('hj', '(', 52, ')', ' is fighting with ', 'oj', '(', 12, ')')
# ('hj', '(', 52, ')', ' is fighting with ', 'oj', '(', 8, ')')
# ('oj', '(', 8, ')', ' is fighting with ', 'hj', '(', 50, ')')
# ('hj', '(', 50, ')', ' is fighting with ', 'oj', '(', 4, ')')
# ('hj', '(', 50, ')', ' is fighting with ', 'oj', '(', 0, ')')
# ('oj', '(', 0, ')', ' is fighting with ', 'hj', '(', 48, ')')
# ('oj', '(', 0, ')', ' is fighting with ', 'hj', '(', 46, ')')
# ('hj', '(', 46, ')', ' is fighting with ', 'oj', '(', -4, ')')
# ------------------
# 6 : hj winner
# ------------------
# 5 : wj 1 : mj
# ('mj', '(', 100, ')', ' is fighting with ', 'wj', '(', 91, ')')
# ('wj', '(', 91, ')', ' is fighting with ', 'mj', '(', 94, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 82, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 73, ')')
# ('wj', '(', 73, ')', ' is fighting with ', 'mj', '(', 88, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'wj', '(', 64, ')')
# ('wj', '(', 64, ')', ' is fighting with ', 'mj', '(', 82, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'wj', '(', 55, ')')
# ('wj', '(', 55, ')', ' is fighting with ', 'mj', '(', 76, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 46, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 37, ')')
# ('wj', '(', 37, ')', ' is fighting with ', 'mj', '(', 70, ')')
# ('wj', '(', 37, ')', ' is fighting with ', 'mj', '(', 64, ')')
# ('wj', '(', 37, ')', ' is fighting with ', 'mj', '(', 58, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'wj', '(', 28, ')')
# ('wj', '(', 28, ')', ' is fighting with ', 'mj', '(', 52, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'wj', '(', 19, ')')
# ('wj', '(', 19, ')', ' is fighting with ', 'mj', '(', 46, ')')
# ('wj', '(', 19, ')', ' is fighting with ', 'mj', '(', 40, ')')
# ('wj', '(', 19, ')', ' is fighting with ', 'mj', '(', 34, ')')
# ('wj', '(', 19, ')', ' is fighting with ', 'mj', '(', 28, ')')
# ('mj', '(', 28, ')', ' is fighting with ', 'wj', '(', 10, ')')
# ('wj', '(', 10, ')', ' is fighting with ', 'mj', '(', 22, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'wj', '(', 1, ')')
# ('wj', '(', 1, ')', ' is fighting with ', 'mj', '(', 16, ')')
# ('mj', '(', 16, ')', ' is fighting with ', 'wj', '(', -8, ')')
# ------------------
# 1 : mj winner

# %%
game.Fight(game.people[0], game.people[1])
game.Log()
# Out:
# nj is gone...by aj
# name: mj , age: 20 , power: 9 , energy: 16
# name: dj , age: 20 , power: 2 , energy: 18
# name: aj , age: 20 , power: 9 , energy: 28
# kj is gone...by dj
# wj is gone...by mj
# name: hj , age: 20 , power: 4 , energy: 46
# oj is gone...by hj

# %%
game.people[1].Print()
game.people[1].PrintHistory()
# Out:
# name: mj , age: 20 , power: 9 , energy: 16
# ---------------------
# ('mj', '(', 100, ')', ' is fighting with ', 'wj', '(', 91, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 82, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 73, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'wj', '(', 64, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'wj', '(', 55, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 46, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 37, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'wj', '(', 28, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'wj', '(', 19, ')')
# ('mj', '(', 28, ')', ' is fighting with ', 'wj', '(', 10, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'wj', '(', 1, ')')
# ('mj', '(', 16, ')', ' is fighting with ', 'wj', '(', -8, ')')
# ---------------------

# %%
game.Fight(game.people[1], game.people[2])
game.people[1].Print()
game.people[1].PrintHistory()
# Out:
# ('dj', '(', 18, ')', ' is fighting with ', 'mj', '(', 14, ')')
# ('mj', '(', 14, ')', ' is fighting with ', 'dj', '(', 9, ')')
# ('dj', '(', 9, ')', ' is fighting with ', 'mj', '(', 12, ')')
# ('dj', '(', 9, ')', ' is fighting with ', 'mj', '(', 10, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'dj', '(', 0, ')')
# ('dj', '(', 0, ')', ' is fighting with ', 'mj', '(', 8, ')')
# ('dj', '(', 0, ')', ' is fighting with ', 'mj', '(', 6, ')')
# ('mj', '(', 6, ')', ' is fighting with ', 'dj', '(', -9, ')')
# name: mj , age: 20 , power: 9 , energy: 6
# ---------------------
# ('mj', '(', 100, ')', ' is fighting with ', 'wj', '(', 91, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 82, ')')
# ('mj', '(', 94, ')', ' is fighting with ', 'wj', '(', 73, ')')
# ('mj', '(', 88, ')', ' is fighting with ', 'wj', '(', 64, ')')
# ('mj', '(', 82, ')', ' is fighting with ', 'wj', '(', 55, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 46, ')')
# ('mj', '(', 76, ')', ' is fighting with ', 'wj', '(', 37, ')')
# ('mj', '(', 58, ')', ' is fighting with ', 'wj', '(', 28, ')')
# ('mj', '(', 52, ')', ' is fighting with ', 'wj', '(', 19, ')')
# ('mj', '(', 28, ')', ' is fighting with ', 'wj', '(', 10, ')')
# ('mj', '(', 22, ')', ' is fighting with ', 'wj', '(', 1, ')')
# ('mj', '(', 16, ')', ' is fighting with ', 'wj', '(', -8, ')')
# ---------------------
# ('mj', '(', 14, ')', ' is fighting with ', 'dj', '(', 9, ')')
# ('mj', '(', 10, ')', ' is fighting with ', 'dj', '(', 0, ')')
# ('mj', '(', 6, ')', ' is fighting with ', 'dj', '(', -9, ')')
# ---------------------
